# %%
# %matplotlib inline
import pyedflib
import numpy as np
import matplotlib.pylab as plt

# %%
f=open("sel100.dat","r")
x = np.fromfile(f, dtype=np.dtype('>f2'))
plt.plot(x[:1000])

# %%
signal_labels
# Out:
# ['squarewave',
#  'ramp',
#  'pulse',
#  'ECG',
#  'noise',
#  'sine 1 Hz',
#  'sine 8 Hz',
#  'sine 8.5 Hz',
#  'sine 15 Hz',
#  'sine 17 Hz',
#  'sine 50 Hz']

# %%
sigbufs[3]
# Out:
# array([ 0.01525902,  0.01525902,  0.01525902, ...,  0.01525902,
#         0.01525902,  0.01525902])

# %%
plt.plot(sigbufs[3][0:1000])
